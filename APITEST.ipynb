# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pandas as pd

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '52be40ee-63df-4191-8382-197ef567656b',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
pd.set_option('display.max_columns',None)
pd.json_normalize(data['data'])
# Out:
#          id                    name symbol                    slug  \
# 0         1                 Bitcoin    BTC                 bitcoin
# 1      1027                Ethereum    ETH                ethereum
# 2       825             Tether USDt   USDT                  tether
# 3      1839                     BNB    BNB                     bnb
# 4      5426                  Solana    SOL                  solana
# ...     ...                     ...    ...                     ...
# 4995  24733                 Aptopad    APD                 aptopad
# 4996  19424  Frax Price Index Share   FPIS  frax-price-index-share
# 4997  27187                    LULU   LULU                    lulu
# 4998  16296             Battle Saga    BTL              battlesaga
# 4999  20642                     CSR    CSR                     csr
#
#       num_market_pairs                date_added  \
# 0                10814  2010-07-13T00:00:00.000Z
# 1                 8380  2015-08-07T00:00:00.000Z
# 2                74197  2015-02-25T00:00:00.000Z
# 3                 2053  2017-07-25T00:00:00.000Z
# 4                  625  2020-04-10T00:00:00.000Z
# ...                ...                       ...
# 4995                 2  2023-04-26T08:33:49.000Z
# 4996                13  2022-04-10T18:20:19.000Z
# 4997                 3  2023-06-26T04:12:46.000Z
# 4998                 2  2021-12-20T16:41:38.000Z
# 4999                 1  2022-06-17T04:57:01.000Z
#
#                                                    tags    max_supply  \
# 0     [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1     [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2     [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3     [marketplace, centralized-exchange, payments, ...           NaN
# 4     [pos, platform, solana-ecosystem, cms-holdings...           NaN
# ...                                                 ...           ...
# 4995                                                 []  1.000000e+08
# 4996                                                 []  1.000000e+08
# 4997                                                 []  4.200000e+11
# 4998  [collectibles-nfts, gaming, smart-contracts, d...  3.000000e+08
# 4999                                                 []  1.000000e+10
#
#       circulating_supply        total_supply  infinite_supply  platform  \
# 0           1.962007e+07            19620068            False       NaN
# 1           1.201836e+08    120183642.226853             True       NaN
# 2           9.623650e+10  99600769237.769424             True       NaN
# 3           1.495461e+08    149546140.644397            False       NaN
# 4           4.362071e+08    568877625.602865             True       NaN
# ...                  ...                 ...              ...       ...
# 4995        0.000000e+00           100000000            False       NaN
# 4996        0.000000e+00           100000000            False       NaN
# 4997        0.000000e+00         42000000000            False       NaN
# 4998        0.000000e+00           300000000            False       NaN
# 4999        0.000000e+00                   0            False       NaN
#
#       cmc_rank  self_reported_circulating_supply  self_reported_market_cap  \
# 0            1                               NaN                       NaN
# 1            2                               NaN                       NaN
# 2            3                               NaN                       NaN
# 3            4                               NaN                       NaN
# 4            5                               NaN                       NaN
# ...        ...                               ...                       ...
# 4995      4997                      1.740000e+07              5.442638e+04
# 4996      4998                      2.602553e+07              2.937574e+07
# 4997      4999                      2.520000e+10              5.811326e+03
# 4998      5000                      2.954262e+07              7.209926e+04
# 4999      5001                      1.250000e+08              8.741790e+05
#
#       tvl_ratio              last_updated  quote.USD.price  \
# 0           NaN  2024-02-06T15:44:00.000Z     4.313308e+04
# 1           NaN  2024-02-06T15:44:00.000Z     2.339946e+03
# 2           NaN  2024-02-06T15:43:00.000Z     9.991335e-01
# 3           NaN  2024-02-06T15:43:00.000Z     3.022407e+02
# 4           NaN  2024-02-06T15:44:00.000Z     9.516657e+01
# ...         ...                       ...              ...
# 4995        NaN  2024-02-06T15:44:00.000Z     3.127953e-03
# 4996        NaN  2024-02-06T15:43:00.000Z     1.128728e+00
# 4997        NaN  2024-02-06T15:43:00.000Z     2.306082e-07
# 4998        NaN  2024-02-06T15:43:00.000Z     2.440516e-03
# 4999        NaN  2024-02-06T15:44:00.000Z     6.993432e-03
#
#       quote.USD.volume_24h  quote.USD.volume_change_24h  \
# 0             1.767409e+10                       4.5467
# 1             8.452930e+09                      16.1558
# 2             3.043005e+10                       4.6296
# 3             6.837101e+08                     -24.2797
# 4             1.632547e+09                       2.0072
# ...                    ...                          ...
# 4995          4.231959e+03                     -51.1034
# 4996          4.191349e+03                     -94.8867
# 4997          4.188046e+03                     -31.9296
# 4998          4.183560e+03                     -35.1487
# 4999          4.170250e+03                     254.6259
#
#       quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# 0                        0.391226                      0.987175
# 1                        0.039734                      1.687654
# 2                       -0.006093                     -0.085142
# 3                       -0.191889                      0.410744
# 4                        0.442258                     -1.308809
# ...                           ...                           ...
# 4995                    -0.004851                      8.849434
# 4996                     0.000000                      0.719033
# 4997                     0.770271                     -9.664010
# 4998                     1.206556                    -13.777774
# 4999                    -2.784642                      7.459145
#
#       quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# 0                       -0.790831                     -2.214289
# 1                        0.688211                      4.976485
# 2                       -0.079084                     -0.155972
# 3                       -2.205320                     -1.091541
# 4                       -9.939174                      0.792701
# ...                           ...                           ...
# 4995                   -22.603529                    -37.891018
# 4996                     3.848965                     -2.202975
# 4997                   -17.632628                     11.090419
# 4998                     8.944668                    -41.203472
# 4999                     2.852380                    -14.787003
#
#       quote.USD.percent_change_60d  quote.USD.percent_change_90d  \
# 0                        -1.849386                     22.494375
# 1                        -0.770403                     24.121642
# 2                        -0.097595                     -0.102964
# 3                        28.496445                     23.431861
# 4                        31.538740                    123.945306
# ...                            ...                           ...
# 4995                     35.122650                    170.673730
# 4996                    -21.281105                      3.487913
# 4997                     37.802673                      1.947968
# 4998                    -76.684691                    293.060788
# 4999                    -25.614715                    -28.068248
#
#       quote.USD.market_cap  quote.USD.market_cap_dominance  \
# 0             8.462739e+11                         51.2858
# 1             2.812233e+11                         17.0427
# 2             9.615311e+10                          5.8271
# 3             4.519893e+10                          2.7391
# 4             4.151234e+10                          2.5157
# ...                    ...                             ...
# 4995          0.000000e+00                          0.0000
# 4996          0.000000e+00                          0.0000
# 4997          0.000000e+00                          0.0000
# 4998          0.000000e+00                          0.0000
# 4999          0.000000e+00                          0.0000
#
#       quote.USD.fully_diluted_market_cap  quote.USD.tvl  \
# 0                           9.057946e+11            NaN
# 1                           2.812233e+11            NaN
# 2                           9.951447e+10            NaN
# 3                           4.519893e+10            NaN
# 4                           5.413813e+10            NaN
# ...                                  ...            ...
# 4995                        3.127953e+05            NaN
# 4996                        1.128728e+08            NaN
# 4997                        9.685543e+04            NaN
# 4998                        7.321549e+05            NaN
# 4999                        6.993432e+07            NaN
#
#         quote.USD.last_updated  platform.id            platform.name  \
# 0     2024-02-06T15:44:00.000Z          NaN                      NaN
# 1     2024-02-06T15:44:00.000Z          NaN                      NaN
# 2     2024-02-06T15:43:00.000Z       1027.0                 Ethereum
# 3     2024-02-06T15:43:00.000Z          NaN                      NaN
# 4     2024-02-06T15:44:00.000Z          NaN                      NaN
# ...                        ...          ...                      ...
# 4995  2024-02-06T15:44:00.000Z      21794.0                    Aptos
# 4996  2024-02-06T15:43:00.000Z       1027.0                 Ethereum
# 4997  2024-02-06T15:43:00.000Z       1839.0  BNB Smart Chain (BEP20)
# 4998  2024-02-06T15:43:00.000Z       1839.0  BNB Smart Chain (BEP20)
# 4999  2024-02-06T15:44:00.000Z       1027.0                 Ethereum
#
#      platform.symbol platform.slug  \
# 0                NaN           NaN
# 1                NaN           NaN
# 2                ETH      ethereum
# 3                NaN           NaN
# 4                NaN           NaN
# ...              ...           ...
# 4995             APT         aptos
# 4996             ETH      ethereum
# 4997             BNB           bnb
# 4998             BNB           bnb
# 4999             ETH      ethereum
#
#                                  platform.token_address
# 0                                                   NaN
# 1                                                   NaN
# 2            0xdac17f958d2ee523a2206206994597c13d831ec7
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4995  0xcc78307c77f1c2c0fdfee17269bfca7876a0b35438c3...
# 4996         0xc2544a32872a91f4a553b404c6950e89de901fdb
# 4997         0x6a97da9951ab920e087c6d12f464afbd2bf9fd14
# 4998         0x708955Db0d4c52FFBf9AA34aF7f3CA8bf07390a8
# 4999         0x75ecb52e403c617679fbd3e77a50f9d10a842387
#
# [5000 rows x 36 columns]
